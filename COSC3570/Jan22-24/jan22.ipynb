# %%
import pandas as pa

#reads in CSV file as data frame
bikes = pa.read_csv('bikes.csv', ';', encoding = 'latin-1', dayfirst = True, index_col = 'Date', parse_dates = True)

#prints all bikes as table (in jupyter)
bikes

#value for Berri 1 column at date 2012-01-04
bikes['Berri 1']['2012-01-04']

#visualization
# %matplotlib inline
bikes['Berri 1'].plot()

# %%
complaints = pa.read_csv('complaints.csv', '>>', encoding = 'latin-1', index_col = 'Unique Key', engine = 'python', parse_dates = True, infer_datetime_format = True)
complaints
# Out:
#               Creâted Date     Closed Date Agency  \
# Unique Key
# 26589651     10/31/13 2:08             NaN   NYPD
# 26593698     10/31/13 2:01             NaN   NYPD
# 26594139     10/31/13 2:00   10/31/13 2:40   NYPD
# 26595721     10/31/13 1:56   10/31/13 2:21   NYPD
# 26590930     10/31/13 1:53             NaN  DOHMH
# 26592370     10/31/13 1:46             NaN   NYPD
# 26595682     10/31/13 1:46             NaN   NYPD
# 26595195     10/31/13 1:44   10/31/13 1:58   NYPD
# 26590540     10/31/13 1:44   10/31/13 2:28   NYPD
# 26594392     10/31/13 1:34   10/31/13 2:23   NYPD
# 26595176     10/31/13 1:25             NaN   NYPD
# 26591982     10/31/13 1:24   10/31/13 1:54   NYPD
# 26594169     10/31/13 1:20   10/31/13 2:12   NYPD
# 26594391     10/31/13 1:20             NaN   NYPD
# 26590917     10/31/13 1:19             NaN  DOHMH
# 26591458     10/31/13 1:14   10/31/13 1:30   NYPD
# 26594086     10/31/13 0:54   10/31/13 2:16   NYPD
# ...
